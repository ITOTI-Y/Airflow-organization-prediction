# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import networkx as nx
from utils.network import network
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig,ax = plt.subplots()
G = network(fig,ax,5)
G.create_edge([0,1,2,3])
G.show([0])

# %%
G.edge_list
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# %%
import numpy as np

a = np.array([(1,2),(2,3)])
a
# Out:
# array([[1, 2],
#        [2, 3]])

# %%
a.reshape((1,4))
# Out:
# array([[1, 2, 2, 3]])

# %%
a = [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# %%
np.array(a)[np.any(np.array(a)==1,axis=1).tolist()]
# Out:
# array([[0, 1],
#        [1, 2],
#        [1, 3]])
